# %%
import numpy as np
import pandas as pd
from os.path import join
import os
import time
from pylab import rcParams
import matplotlib.pyplot as plt

import nilmtk
from nilmtk import DataSet, TimeFrame, MeterGroup, HDFDataStore
from nilmtk.disaggregate import CombinatorialOptimisation, FHMM, Hart85
from nilmtk.utils import print_dict
from nilmtk.metrics import f1_score

import warnings
warnings.filterwarnings("ignore")
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 27 days

# %%
import sys

# %%
sys.path.append("../../code/common/")

# %%
ds = DataSet("/Users/nipunbatra/Downloads/wikienergy-2.h5")
fridges = nilmtk.global_meter_group.select_using_appliances(type='fridge')

# %%
fridges_id_building_id = {i:fridges.meters[i].building() for i in range(len(fridges.meters))}

# %%
fridge_id_building_id_ser = pd.Series(fridges_id_building_id)

# %%
fridge_id_building_id_ser.head()
# Out:
# 0      1
# 1      1
# 2     10
# 3    101
# 4    102
# dtype: int64

# %%
from fridge_compressor_durations_optimised import compressor_powers, defrost_power

# %%
fridge_ids_to_consider = compressor_powers.keys()

# %%
len(fridge_ids_to_consider)
# Out:
# 96

# %%
building_ids_to_consider = fridge_id_building_id_ser[fridge_ids_to_consider]

# %%
building_ids_to_consider.head()
# Out:
# 1       1
# 2      10
# 8     105
# 11     11
# 13    112
# dtype: int64

# %%
out = {}
for f_id, b_id in building_ids_to_consider.iteritems():
    try:
        print "*"*80
        print f_id
        print "*"*80
        start = time.time()
        out[f_id] = {}
        # Need to put it here to ensure that we have a new instance of the algorithm each time
        cls_dict = {"CO": CombinatorialOptimisation(), "FHMM":FHMM(), "Hart":Hart85()}
        #cls_dict = {"FHMM":FHMM()}
        elec = ds.buildings[b_id].elec
        mains = elec.mains()
        elec.appliances
        fridge_instance = fridges.meters[f_id].appliances[0].identifier.instance
        # Dividing train, test
        train_fraction = 0.3
        train = DataSet("/Users/nipunbatra/Downloads/wikienergy-2.h5")
        test = DataSet("/Users/nipunbatra/Downloads/wikienergy-2.h5")
        split_point = elec.train_test_split(train_fraction=train_fraction).date()
        train.set_window(end=split_point)
        test.set_window(start=split_point)
        train_elec = train.buildings[b_id].elec
        test_elec = test.buildings[b_id].elec
        test_mains = test_elec.mains()

        # Fridge elec
        fridge_elec_train = train_elec[('fridge', fridge_instance)]
        fridge_elec_test = test_elec[('fridge', fridge_instance)]
        fridge_elec_mg = MeterGroup([fridge_elec_train])
        fridge_df_train = fridge_elec_train.load().next()[('power','active')]
        fridge_power = fridge_df_train[(fridge_df_train>compressor_powers[f_id][0])&(fridge_df_train<compressor_powers[f_id][1])]
        fridge_compressor_gt = fridge_power.mean()
        out[f_id]["GT"] = fridge_compressor_gt

        for clf_name, clf  in cls_dict.iteritems():

            if clf_name =="Hart":
                clf.train(train_elec.mains())
                d = (clf.centroids-fridge_power).abs()
                fridge_num = d.sort(ascending=True).head(1).index.values[0]
                fridge_identifier_tuple = ('unknown', fridge_num)
                fridge_compressor_algo = clf.centroids.ix[fridge_num][('power', 'active')]
            elif clf_name=="CO":
                clf.train(fridge_elec_mg)
                fridge_compressor_algo = clf.model[0]['states'][1]
            else:
                # FHMM
                clf.train(fridge_elec_mg)
                fridge_compressor_algo = clf.model.means_[1][0]
            out[f_id][clf_name] = fridge_compressor_algo
    except:
        pass
# Out:
# ********************************************************************************
# 1
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=1, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=1, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 2
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=7, building=10, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=7, building=10, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 8
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=105, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=105, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 11
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=11, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=11, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 13
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=112, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=112, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 14
# ********************************************************************************
# ********************************************************************************
# 15
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=116, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=116, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 18
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=12, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=12, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 22
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=122, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=122, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 25
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=126, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=126, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 29
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=130, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=130, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 33
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=135, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=135, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 34
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=136, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=136, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 35
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=21, building=137, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=21, building=137, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 37
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=142, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=142, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 42
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=8, building=149, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=8, building=149, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 43
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=15, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=15, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 44
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=152, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=152, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 45
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=12, building=153, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=12, building=153, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 46
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=154, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=154, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 47
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=155, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=155, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 50
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=158, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=158, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 51
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=159, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=159, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 52
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=9, building=16, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=9, building=16, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 54
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=160, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=160, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 55
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=161, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=161, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 57
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=165, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=165, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 58
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=167, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=167, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 59
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=169, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=169, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 60
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=170, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=170, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 61
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=171, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=171, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 67
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=177, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=177, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 68
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=178, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=178, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 70
# ********************************************************************************
# ********************************************************************************
# 72
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=182, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=182, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 75
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=17, building=186, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=17, building=186, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 76
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=187, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=187, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 78
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=13, building=19, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=13, building=19, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 79
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=7, building=190, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=7, building=190, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 83
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=6, building=197, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=6, building=197, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 84
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=18, building=198, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=18, building=198, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 87
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=200, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=200, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 88
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=202, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=202, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 89
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=203, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=203, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 92
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=8, building=209, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=8, building=209, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 93
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=210, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=210, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 95
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=213, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=213, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 97
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=12, building=219, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=12, building=219, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 99
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=222, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=222, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 100
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=223, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=223, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 102
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=224, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=224, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 103
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=225, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=225, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 104
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=17, building=225, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=17, building=225, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 106
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=228, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=228, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 107
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=17, building=230, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=17, building=230, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 109
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=235, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=235, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 110
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=236, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=236, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 112
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=238, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=238, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 114
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=24, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=24, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 115
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=7, building=25, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=7, building=25, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 116
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=26, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=26, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 118
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=28, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=28, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 119
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=29, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=29, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 123
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=34, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=34, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 124
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=35, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=35, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 125
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=35, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=35, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 126
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=9, building=36, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=9, building=36, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 128
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=39, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=39, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 129
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=4, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=4, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 130
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=41, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=41, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 131
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=42, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=42, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 133
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=13, building=46, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=13, building=46, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 134
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=46, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=46, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=2)])'
# Done training!
# ********************************************************************************
# 135
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=49, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=49, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 136
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=9, building=5, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=9, building=5, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 138
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=51, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=51, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 139
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=9, building=52, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=9, building=52, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 140
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=9, building=53, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=9, building=53, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 142
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=56, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=56, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 144
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=58, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=58, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 145
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=18, building=60, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=18, building=60, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 146
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=14, building=61, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=14, building=61, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 149
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=66, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=66, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 151
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=15, building=73, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=15, building=73, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 152
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=13, building=74, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=13, building=74, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 153
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=75, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=75, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 154
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=8, building=76, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=8, building=76, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 155
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=7, building=77, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=7, building=77, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 157
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=8, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=8, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 158
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=21, building=80, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=21, building=80, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 159
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=12, building=81, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=12, building=81, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 161
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=10, building=84, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=10, building=84, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 163
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=88, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=88, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 167
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=16, building=91, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=16, building=91, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 169
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=11, building=93, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=11, building=93, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!
# ********************************************************************************
# 170
# ********************************************************************************
# Training model for submeter 'ElecMeter(instance=17, building=96, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Finding Edges, please wait ...
# Edge detection complete.
# Creating transition frame ...
# Transition frame created.
# Creating states frame ...
# States frame created.
# Finished.
# Training model for submeter 'ElecMeter(instance=17, building=96, dataset='WikiEnergy', appliances=[Appliance(type='fridge', instance=1)])'
# Done training!

# %%
from sklearn import linear_model

# %%
d = pd.DataFrame(out).T.dropna()

# %%
d
# Out:
#       CO        FHMM          GT         Hart
# 1    100   98.980790  100.716307   118.513791
# 2    104  117.215331  104.665396   116.953427
# 8     54   97.761948  156.159758   144.960955
# 11   134  143.885069  145.586608   143.426608
# 13   131  130.102571  130.095643   141.391675
# 15   120  103.383206  138.865447   136.685392
# 18   111  115.821022  117.763459   153.974019
# 22   118   95.700560  131.011641   129.767271
# 25    20  118.635197  133.212201   808.710551
# 29    39   67.841159  101.737067   120.719609
# 33   121  107.597235  124.149521   126.578155
# 34    20  128.003188  144.539704   133.518018
# 35   156  127.800566  167.943504   160.475629
# 37   127   92.639087  135.848315   127.631251
# 42    67   66.658341   68.678739   115.268372
# 43   111   83.584967  113.134173   120.486779
# 44    26  134.337617  134.661600   552.882166
# 45   128  125.915391  135.197636   129.483680
# 46    15  127.507703  148.266036   150.780253
# 47    50  119.605418  139.463437   151.633269
# 50    15  139.588636  143.685394   167.859306
# 51   113  113.970967  118.010281   596.892566
# 52   149  114.863439  161.333665   136.754504
# 54    86   90.200251  102.965765    97.072437
# 55    17  108.735714  107.775494   127.954640
# 57   116  129.694486  130.332207   140.029789
# 58    21  164.396162  168.229259   346.912817
# 59   101   99.702695  101.950946   130.553807
# 60   106   54.149415  106.983174   284.696876
# 61   116  118.397183  118.481003   488.257888
# ..   ...         ...         ...          ...
# 126  178  169.958798  170.596719   276.153467
# 128   17  126.686155  127.080390   128.195830
# 129  115   75.087799  114.640754   141.930420
# 130   18  122.492449  123.341302   131.611652
# 131  124  135.616939  145.767483   127.636827
# 133   81   81.388117   80.847370   141.593147
# 134   25   54.980449  106.654441   141.593147
# 135  131  134.226701  140.999532   134.041188
# 136  109  105.081659  110.361056   134.639527
# 138   91   93.263537   93.903394   112.497812
# 139  104  110.964232  110.701765  4943.898170
# 140   81   81.459688   84.486323    88.936557
# 142   26   90.386019  149.167076   124.224665
# 144  189  192.852351  191.105510   297.561994
# 145   98  101.007775  103.500881   113.964202
# 146  114  130.341197  131.812552   816.669846
# 149  122  100.237363  130.099509   413.655110
# 151  109  105.967608  107.348904   147.276498
# 152  140  143.026116  149.406909   142.139102
# 153  163  168.398475  169.178541   195.834591
# 154   27  148.994924  151.187093   187.419281
# 155   16  239.597099  240.793127   136.643183
# 157   16  165.927967  164.700346   223.076565
# 158   19  156.108828  156.422669   205.520957
# 159  106  122.490762  131.125438   130.279355
# 161   29  108.533811  110.991908   689.448348
# 163  136  138.587717  139.532542   322.854458
# 167  133  135.589243  137.254499   459.172559
# 169   15  165.774624  171.834978   152.606418
# 170  139  137.222092  138.098547   132.183377
#
# [94 rows x 4 columns]

# %%
from common_functions import latexify, format_axes
latexify(columns=2, fig_height=2.6)
fig, ax = plt.subplots(ncols=3, sharey=True)
for i, algo in enumerate(["CO", "FHMM", "Hart"]):
    x = d[["GT"]]
    y = d[[algo]]
   

    # Train the model using the training sets
    
    model_ransac = linear_model.RANSACRegressor(linear_model.LinearRegression())
    model_ransac.fit(x, y)
    ax[i].scatter(x, y, color="gray", alpha=0.5)
    
    #ax[i].set_xlabel("Actual energy (kWh)")
    
    ax[i].plot(x, model_ransac.predict(x), color='black')
    format_axes(ax[i])
    title = algo + "\n" + "y = %0.2f x %s %0.2f" %(model_ransac.estimator_.coef_[0], 
                                                   sign(model_ransac.estimator_.intercept_[0]),
                                                   model_ransac.estimator_.intercept_[0])
    #title = title +"\n" + str(scipy.stats.pearsonr(x, y))
    ax[i].set_title(title)
#ax[0].set_ylabel("Predicted energy (kWh)")
plt.tight_layout()
plt.savefig("../../figures/fridge/disag_algos_power_level.pdf", bbox_inches="tight")
plt.savefig("../../figures/fridge/disag_algos_power_level.png", bbox_inches="tight")

# %%
pd.DataFrame(out).T
# Out:
#     CO        FHMM          GT        Hart
# 1   99   98.980790  100.716307  118.513791
# 2  103  117.215331  104.665396  116.953427
